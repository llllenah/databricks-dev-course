# %% [markdown]
# ## Safe checkpoint reload
# Dev/test only - demonstrates idempotent reload.

# %%
catalog = "dbr_dev_ua5816bd"
login = "lena066636"
checkpoint_path = f"abfss://{login}@dlsua5816bd.dfs.core.windows.net/_checkpoints/bronze_streaming"
bronze_table = f"{catalog}.{login}_bronze.orders_streaming"

# %%
before = spark.table(bronze_table).count()

# %%
# rerun 02's write stream cell here without touching source files

# %%
after = spark.table(bronze_table).count()
assert after == before, "reload duplicated rows - checkpoint not respected"

# %%
# full reset (only when intentionally reprocessing everything)
# dbutils.fs.rm(checkpoint_path, recurse=True)
