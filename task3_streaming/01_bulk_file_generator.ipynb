# %% [markdown]
# ## Setup: generate 1000 test files
# Dev-only, not scheduled as a job.

# %%
import random
from datetime import datetime, timedelta

login = "lena066636"
raw_path = f"abfss://{login}@dlsua5816bd.dfs.core.windows.net/raw_streaming/"

# %%
for i in range(1000):
    ts = datetime.now() - timedelta(minutes=i)
    row = f"order_id,customer,amount,ts\n{i},cust_{i%50},{round(random.uniform(5,200),2)},{ts.isoformat()}\n"
    dbutils.fs.put(f"{raw_path}orders_{i:04d}.csv", row, overwrite=True)
