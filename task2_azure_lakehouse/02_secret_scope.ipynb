# %% [markdown]
# ## Task 4: Secret scope backed by Azure Key Vault
# Scope created via UI: `<workspace-url>#secrets/createScope`.

# %%
login = "lena066636"
scope_name = f"{login}-scope"

dbutils.secrets.list(scope_name)
