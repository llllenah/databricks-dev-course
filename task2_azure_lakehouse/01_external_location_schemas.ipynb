# %% [markdown]
# ## Task 2-3: External location + bronze/silver/gold schemas

# %%
catalog = "dbr_dev_ua5816bd"
login = "lena066636"
base_url = f"abfss://{login}@dlsua5816bd.dfs.core.windows.net"

# %%
# external location created via UI, credential: databricks_uc_connector_ua5816bd
spark.sql(f"DESCRIBE EXTERNAL LOCATION {login}_location").show(truncate=False)

# %%
for layer in ["bronze", "silver", "gold"]:
    spark.sql(f"""
        CREATE SCHEMA IF NOT EXISTS {catalog}.{login}_{layer}
        MANAGED LOCATION '{base_url}/{layer}'
    """)

# %%
spark.sql(f"SHOW SCHEMAS IN {catalog}").show(truncate=False)
